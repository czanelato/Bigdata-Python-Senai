# %% [markdown]
# # Situação Problema

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression

# %%
# Etapa 2 : Importando o dataset

caminho = "C:\\Users\\FIC\\Documents\\Carlos Zanelato_Python\\Arquivos\\IceCreamData.csv"
dados = pd.read_csv(caminho)

# %%
# Etapa 3 Visualizando o dataframe

dados.head() # Cabeçalho
# Out:
#    Temperature     Revenue
# 0    24.566884  534.799028
# 1    26.005191  625.190122
# 2    27.790554  660.632289
# 3    20.595335  487.706960
# 4    11.503498  316.240194

# %%
dados.tail() # Últimas linhas
# Out:
#      Temperature     Revenue
# 495    22.274899  524.746364
# 496    32.893092  755.818399
# 497    12.588157  306.090719
# 498    22.362402  566.217304
# 499    28.957736  655.660388

# %%
dados.describe() # Descrição dos dados
# Out:
#        Temperature      Revenue
# count   500.000000   500.000000
# mean     22.232225   521.570777
# std       8.096388   175.404751
# min       0.000000    10.000000
# 25%      17.122258   405.558681
# 50%      22.392791   529.368565
# 75%      27.740674   642.257922
# max      45.000000  1000.000000

# %%
dados.info() # Tipos de dados
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 2 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Temperature  500 non-null    float64
#  1   Revenue      500 non-null    float64
# dtypes: float64(2)
# memory usage: 7.9 KB

# %%
# Etapa 4
# Gerar algumas visualizações gráficas

sns.jointplot(data = dados, x= 'Temperature', y= 'Revenue', color = 'gray')

# %%
sns.pairplot(dados)

# %%
sns.lmplot(x= 'Temperature', y= 'Revenue', data=dados)

# %%
# Etapa 5
# Criação da variável dependente (Y) > Resposta
y = dados ['Revenue']

# Criação da variável independente (X) > Entrada
x = dados [['Temperature']]

# Separar os dados para teste e treino
x_train, x_test, y_train, y_test = train_test_split(x,y,test_size=0.25)

# %%
# Etapa 6
# Treinando o modelo

modelo = LinearRegression() # Criação do modelo

modelo.fit(x_train,y_train) #treinar com estes dados

print('Coeficiente Linear (b):', modelo.intercept_)
print('Coeficiente Angular (a):', modelo.coef_)
# Out:
# Coeficiente Linear (b): 41.539248472183374
# Coeficiente Angular (a): [21.57332291]

# %%
# Etapa 7
# Testando o modelo

y_predict=modelo.predict(x_test)
y_predict
# Out:
# array([437.34110688, 446.61785837, 702.44462096, 256.2878066 ,
#        539.24909435, 626.78312819, 911.02544589, 801.29214047,
#        572.86023695, 450.9575795 , 410.24124251, 745.53843479,
#        558.96765039, 445.14324365, 663.4929505 , 457.20940508,
#        546.03452226, 443.53466766, 464.76201056, 462.10563791,
#        483.2535213 , 729.54418137, 509.76563236, 472.51960166,
#        469.069425  , 390.83933819, 874.89217129, 580.01900265,
#        625.49905618, 473.35917218, 724.75483422, 376.38228542,
#        545.25550267, 550.47611457, 731.97975041, 127.54180006,
#        394.58549113, 475.24718505, 660.72115345, 349.25121566,
#        524.73804485, 682.35718073, 500.66089468, 469.7533291 ,
#        942.58336237, 447.37280278, 709.55905866, 572.57174057,
#        440.1071335 , 392.29388109, 747.34029308, 255.12147195,
#        690.57675914, 749.25280807, 527.51608845, 226.78825352,
#        451.96332307, 655.62243881, 726.23163647, 178.58290571,
# ...
