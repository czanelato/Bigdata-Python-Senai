# %% [markdown]
# # Exercicio 01
#     Leia o lucro total de todos os meses e mostre-o usando um grafico de linhas.
#     Arquivo: company_sales_data.csv
#     Dados de lucro total fornecidos para cada mes. O grafico de linha gerado deve incluir as seguintes propriedades:
#
#     Nome do rotulo X = Numero do mes
#
#     Nome do rotulo Y = lucro total
#
# ![image.png](attachment:image.png)

# %%
# !pip install pandas
# Out:
# ...
#      --------------------------------------- 10.6/10.6 MB 11.1 MB/s eta 0:00:00
# ...
# [notice] A new release of pip available: 22.3 -> 23.3.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
# Importar as bibliotecas 
import pandas as pd
import matplotlib.pyplot as plt
import os

# Mapear o caminho do arquivo
caminhoArquivo = "C:\\Users\\FIC\\Documents\\Carlos Zanelato_Python\\Arquivos\\company_sales_data.csv"

# Alocar os dados em um Dataframe
df = pd.read_csv(caminhoArquivo)

# Visualizar o cabeçalho do Dataframe
df.head()
# Out:
#    month_number  facecream  facewash  toothpaste  bathingsoap  shampoo  \
# 0             1       2500      1500        5200         9200     1200
# 1             2       2630      1200        5100         6100     2100
# 2             3       2140      1340        4550         9550     3550
# 3             4       3400      1130        5870         8870     1870
# 4             5       3600      1740        4560         7760     1560
#
#    moisturizer  total_units  total_profit
# 0         1500        21100        211000
# 1         1200        18330        183300
# 2         1340        22470        224700
# 3         1130        22270        222700
# 4         1740        20960        209600

# %%
# Selecionar os dados que vão ser apresentados no gráfico

listalucro = df['total_profit'].to_list()
listameses = df['month_number'].to_list()

# Criar o gráfico utilizando os dados listados anteriormente
plt.plot(listameses, listalucro, label = 'Lucro mensal do ano anterior')

plt.xlabel('Numero do Mês') # Título do eixo X
plt.ylabel('Lucro') # Título do eixo Y
plt.title('Lucro mensal da empresa') # Título do gráfico
plt.legend() # Legenda do gráfico
